# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Load the MNIST dataset

# %%
(train_data,train_target),(test_data,test_target) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Visualize the dataset

# %%
fig, axs = plt.subplots(2, 5, figsize=(16,8))
random_numbers = np.random.randint(0, 60000, 10)
print('Target labels: ',train_target[random_numbers])
for idx, ax in enumerate(axs.ravel()):
    ax.imshow(train_data[random_numbers[idx]],cmap='gray')
plt.show()
# Out:
# Target labels:  [1 3 3 0 3 8 9 2 0 1]

# %% [markdown]
# Pre-processing stage

# %%
new_train_data = train_data/255.0
new_test_data=test_data/255.0

new_train_target = to_categorical(train_target)
new_test_target = to_categorical(test_target)

# %% [markdown]
# Create the Model architecture

# %%
model=Sequential()

model.add(Flatten(input_shape=(28,28)))

model.add(Dense(64,activation='relu'))
model.add(Dense(64,input_dim=64,activation='relu'))
model.add(Dense(32,input_dim=64,activation='relu'))
model.add(Dense(10,input_dim=32,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 56,810 (221.91 KB)
#  Trainable params: 56,810 (221.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Train the model

# %%
train_info = model.fit(new_train_data , new_train_target , epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8263 - loss: 0.5631
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9585 - loss: 0.1367
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9688 - loss: 0.0961
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9770 - loss: 0.0721
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9821 - loss: 0.0579
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9822 - loss: 0.0538
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9859 - loss: 0.0435
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9870 - loss: 0.0392
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9882 - loss: 0.0353
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9898 - loss: 0.0299

# %% [markdown]
# Plot the loss and accuracy graphs

# %%
plt.plot(train_info.history['loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Model loss')
plt.show()

# %%
plt.plot(train_info.history['accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.title('Model accuracy')
plt.show()

# %% [markdown]
# Test the performance of Model

# %%
loss, acc = model.evaluate(new_test_data , new_test_target)
print(f'Loss of the Test dataset is: {loss}\nAccuracy of the test dataset is: {acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9708 - loss: 0.1151
# Loss of the Test dataset is: 0.0961211547255516
# Accuracy of the test dataset is: 0.9751999974250793

# %% [markdown]
# Save the model weights

# %%
model.save_weights('MNIST_WEIGHTS_V1.weights.h5')

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l1_l2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Load and preprocess the data
(train_data, train_target), (test_data, test_target) = mnist.load_data()

new_train_data = train_data / 255.0
new_test_data = test_data / 255.0

new_train_target = to_categorical(train_target)
new_test_target = to_categorical(test_target)

# Define the improved model with L1 and L2 regularization
model_with_regularization = Sequential()
model_with_regularization.add(Flatten(input_shape=(28, 28)))

# Adding layers with L1 and L2 regularization
model_with_regularization.add(Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
model_with_regularization.add(Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
model_with_regularization.add(Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
model_with_regularization.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))
model_with_regularization.add(Dense(10, activation='softmax', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))

# Compile the model with a smaller learning rate
model_with_regularization.compile(loss='categorical_crossentropy',
                                  optimizer=Adam(learning_rate=0.0001),
                                  metrics=['accuracy'])

# Adding early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with new hyperparameters
train_info = model_with_regularization.fit(new_train_data, new_train_target,
                                           epochs=50, batch_size=256, validation_split=0.2,
                                           callbacks=[early_stopping])

# Evaluate the improved model
loss, acc = model_with_regularization.evaluate(new_test_data, new_test_target)
print(f'Loss of the Test dataset is: {loss}\nAccuracy of the test dataset is: {acc}')

# Plotting the loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_info.history['loss'], label='Training Loss')
plt.plot(train_info.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_info.history['accuracy'], label='Training Accuracy')
plt.plot(train_info.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()

plt.show()

# Generating the confusion matrix
y_pred = model_with_regularization.predict(new_test_data)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(new_test_target, axis=1)

conf_matrix = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(conf_matrix, display_labels=range(10))
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.3577 - loss: 2.1166 - val_accuracy: 0.8411 - val_loss: 0.8218
# Epoch 2/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8573 - loss: 0.6973 - val_accuracy: 0.9061 - val_loss: 0.4549
# Epoch 3/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9071 - loss: 0.4474 - val_accuracy: 0.9215 - val_loss: 0.3774
# Epoch 4/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9198 - loss: 0.3753 - val_accuracy: 0.9327 - val_loss: 0.3380
# Epoch 5/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9320 - loss: 0.3365 - val_accuracy: 0.9388 - val_loss: 0.3137
# Epoch 6/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9379 - loss: 0.3115 - val_accuracy: 0.9427 - val_loss: 0.2942
# Epoch 7/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9428 - loss: 0.2903 - val_accuracy: 0.9471 - val_loss: 0.2789
# Epoch 8/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9447 - loss: 0.2801 - val_accuracy: 0.9497 - val_loss: 0.2676
# Epoch 9/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9514 - loss: 0.2604 - val_accuracy: 0.9519 - val_loss: 0.2570
# Epoch 10/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9538 - loss: 0.2500 - val_accuracy: 0.9538 - val_loss: 0.2501
# Epoch 11/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9562 - loss: 0.2445 - val_accuracy: 0.9548 - val_loss: 0.2460
# Epoch 12/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9588 - loss: 0.2295 - val_accuracy: 0.9577 - val_loss: 0.2379
# Epoch 13/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9627 - loss: 0.2206 - val_accuracy: 0.9596 - val_loss: 0.2335
# Epoch 14/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9630 - loss: 0.2149 - val_accuracy: 0.9596 - val_loss: 0.2270
# Epoch 15/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9666 - loss: 0.2045 - val_accuracy: 0.9620 - val_loss: 0.2217
# Epoch 16/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9665 - loss: 0.2048 - val_accuracy: 0.9630 - val_loss: 0.2173
# Epoch 17/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9678 - loss: 0.1981 - val_accuracy: 0.9631 - val_loss: 0.2146
# Epoch 18/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9721 - loss: 0.1885 - val_accuracy: 0.9639 - val_loss: 0.2144
# Epoch 19/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9723 - loss: 0.1854 - val_accuracy: 0.9648 - val_loss: 0.2083
# Epoch 20/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9727 - loss: 0.1822 - val_accuracy: 0.9656 - val_loss: 0.2073
# Epoch 21/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9743 - loss: 0.1769 - val_accuracy: 0.9668 - val_loss: 0.2022
# Epoch 22/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9762 - loss: 0.1711 - val_accuracy: 0.9673 - val_loss: 0.2002
# Epoch 23/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9786 - loss: 0.1662 - val_accuracy: 0.9681 - val_loss: 0.1997
# Epoch 24/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9776 - loss: 0.1658 - val_accuracy: 0.9681 - val_loss: 0.1957
# Epoch 25/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9796 - loss: 0.1591 - val_accuracy: 0.9685 - val_loss: 0.1970
# Epoch 26/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9803 - loss: 0.1566 - val_accuracy: 0.9665 - val_loss: 0.1967
# Epoch 27/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9808 - loss: 0.1558 - val_accuracy: 0.9694 - val_loss: 0.1931
# Epoch 28/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9812 - loss: 0.1554 - val_accuracy: 0.9682 - val_loss: 0.1915
# Epoch 29/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9838 - loss: 0.1489 - val_accuracy: 0.9668 - val_loss: 0.1958
# Epoch 30/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9824 - loss: 0.1480 - val_accuracy: 0.9689 - val_loss: 0.1916
# Epoch 31/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9840 - loss: 0.1446 - val_accuracy: 0.9709 - val_loss: 0.1861
# Epoch 32/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9845 - loss: 0.1424 - val_accuracy: 0.9707 - val_loss: 0.1855
# Epoch 33/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9846 - loss: 0.1411 - val_accuracy: 0.9700 - val_loss: 0.1880
# Epoch 34/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9863 - loss: 0.1364 - val_accuracy: 0.9711 - val_loss: 0.1839
# Epoch 35/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9871 - loss: 0.1365 - val_accuracy: 0.9712 - val_loss: 0.1833
# Epoch 36/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9881 - loss: 0.1309 - val_accuracy: 0.9704 - val_loss: 0.1839
# Epoch 37/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9894 - loss: 0.1294 - val_accuracy: 0.9717 - val_loss: 0.1829
# Epoch 38/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9895 - loss: 0.1270 - val_accuracy: 0.9720 - val_loss: 0.1806
# Epoch 39/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9898 - loss: 0.1261 - val_accuracy: 0.9715 - val_loss: 0.1822
# Epoch 40/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9899 - loss: 0.1252 - val_accuracy: 0.9713 - val_loss: 0.1827
# Epoch 41/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9902 - loss: 0.1248 - val_accuracy: 0.9701 - val_loss: 0.1827
# Epoch 42/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9918 - loss: 0.1205 - val_accuracy: 0.9725 - val_loss: 0.1789
# Epoch 43/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9912 - loss: 0.1224 - val_accuracy: 0.9728 - val_loss: 0.1782
# Epoch 44/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9920 - loss: 0.1194 - val_accuracy: 0.9724 - val_loss: 0.1778
# Epoch 45/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9921 - loss: 0.1172 - val_accuracy: 0.9713 - val_loss: 0.1821
# Epoch 46/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9919 - loss: 0.1181 - val_accuracy: 0.9713 - val_loss: 0.1790
# Epoch 47/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9928 - loss: 0.1166 - val_accuracy: 0.9718 - val_loss: 0.1788
# Epoch 48/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9927 - loss: 0.1138 - val_accuracy: 0.9728 - val_loss: 0.1765
# Epoch 49/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9932 - loss: 0.1134 - val_accuracy: 0.9719 - val_loss: 0.1788
# Epoch 50/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9941 - loss: 0.1114 - val_accuracy: 0.9728 - val_loss: 0.1777
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9724 - loss: 0.1815
# Loss of the Test dataset is: 0.1676216870546341
# Accuracy of the test dataset is: 0.9758999943733215
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
